# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split

# %%
data = load_wine()

# %%
data.data
# Out:
# array([[1.423e+01, 1.710e+00, 2.430e+00, ..., 1.040e+00, 3.920e+00,
#         1.065e+03],
#        [1.320e+01, 1.780e+00, 2.140e+00, ..., 1.050e+00, 3.400e+00,
#         1.050e+03],
#        [1.316e+01, 2.360e+00, 2.670e+00, ..., 1.030e+00, 3.170e+00,
#         1.185e+03],
#        ...,
#        [1.327e+01, 4.280e+00, 2.260e+00, ..., 5.900e-01, 1.560e+00,
#         8.350e+02],
#        [1.317e+01, 2.590e+00, 2.370e+00, ..., 6.000e-01, 1.620e+00,
#         8.400e+02],
#        [1.413e+01, 4.100e+00, 2.740e+00, ..., 6.100e-01, 1.600e+00,
#         5.600e+02]])

# %%
train_test_split(data.data, test_size=0.4, train_size=0.6)
# Out:
# [array([[1.229e+01, 2.830e+00, 2.220e+00, ..., 1.150e+00, 3.300e+00,
#          2.900e+02],
#         [1.324e+01, 2.590e+00, 2.870e+00, ..., 1.040e+00, 2.930e+00,
#          7.350e+02],
#         [1.388e+01, 5.040e+00, 2.230e+00, ..., 5.800e-01, 1.330e+00,
#          4.150e+02],
#         ...,
#         [1.308e+01, 3.900e+00, 2.360e+00, ..., 5.700e-01, 1.330e+00,
#          5.500e+02],
#         [1.233e+01, 9.900e-01, 1.950e+00, ..., 1.060e+00, 2.310e+00,
#          7.500e+02],
#         [1.237e+01, 1.630e+00, 2.300e+00, ..., 8.900e-01, 2.780e+00,
#          3.420e+02]]),
#  array([[1.307e+01, 1.500e+00, 2.100e+00, 1.550e+01, 9.800e+01, 2.400e+00,
#          2.640e+00, 2.800e-01, 1.370e+00, 3.700e+00, 1.180e+00, 2.690e+00,
#          1.020e+03],
#         [1.340e+01, 4.600e+00, 2.860e+00, 2.500e+01, 1.120e+02, 1.980e+00,
#          9.600e-01, 2.700e-01, 1.110e+00, 8.500e+00, 6.700e-01, 1.920e+00,
#          6.300e+02],
# ...
